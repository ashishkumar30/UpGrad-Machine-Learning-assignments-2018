# %%
import pandas as pd
import numpy as np
a=pd.read_csv("C:/Users/sony vaio\Desktop/mahine jupyter/weather.csv ")
a
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
a.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
# Remove the missing values (if any)

a.dropna(how='any',inplace=True) #removing full rows having missing values
a.isnull().sum() #checking if all missing value rows are deleted or not
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
#Once again , Import the dataset and this time replace the missing null values with mean of the column series.

b=pd.read_csv("C:/Users/sony vaio\Desktop/mahine jupyter/weather.csv ")

b.fillna(b.mean()) #replacing missing value with it's column mean

#
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation   Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4   6.300000
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4   9.700000
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8   3.300000
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2   9.100000
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6  10.600000
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8   8.200000
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2   8.400000
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6   4.600000
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0   4.100000
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4   7.700000
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2  11.900000
# ...

# %%
b.isnull().sum() #cheching all missing values are filled or not
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
#Find individual data types and copy the temperature column to a pandas series.

b.dtypes #displaying datatype for each column
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
mintemp = pd.Series(b['MinTemp'],name='MinTemp')
mintemp
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
# 5       6.2
# 6       6.1
# 7       8.3
# 8       8.8
# 9       8.4
# 10      9.1
# 11      8.5
# 12     10.1
# 13     12.1
# 14     10.1
# 15     12.4
# 16     13.8
# 17     11.7
# 18     12.4
# 19     15.6
# 20     15.3
# 21     16.4
# 22     12.8
# 23     12.0
# 24     15.4
# 25     15.6
# 26     13.3
# 27     12.9
# 28     15.1
# 29     13.6
#        ...
# 336     5.6
# 337    16.8
# 338    14.4
# 339    10.3
# 340    11.2
# 341     0.3
# 342     0.5
# 343     0.5
# 344     4.6
# 345     8.2
# 346     4.5
# 347     6.7
# 348    11.9
# 349     9.2
# 350     4.4
# 351     5.0
# 352     6.7
# 353     8.3
# 354    11.3
# 355     9.0
# 356     3.4
# 357     3.2
# 358     0.9
# 359     3.3
# 360     7.9
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
maxtemp = pd.Series(b['MaxTemp'],name='MaxTemp')
maxtemp
# Out:
# 0      24.3
# 1      26.9
# 2      23.4
# 3      15.5
# 4      16.1
# 5      16.9
# 6      18.2
# 7      17.0
# 8      19.5
# 9      22.8
# 10     25.2
# 11     27.3
# 12     27.9
# 13     30.9
# 14     31.2
# 15     32.1
# 16     31.2
# 17     30.0
# 18     32.3
# 19     33.4
# 20     33.4
# 21     19.4
# 22     18.5
# 23     24.3
# 24     28.4
# 25     26.9
# 26     22.2
# 27     28.0
# 28     24.3
# 29     24.1
#        ...
# 336    27.6
# 337    28.9
# 338    20.7
# 339    21.3
# 340    18.0
# 341    16.0
# 342    17.9
# 343    20.0
# 344    22.0
# 345    22.4
# 346    23.9
# 347    26.1
# 348    21.1
# 349    19.6
# 350    21.0
# 351    24.1
# 352    24.7
# 353    28.5
# 354    27.4
# 355    20.6
# 356    15.0
# 357    18.0
# 358    20.7
# 359    25.5
# 360    26.1
# 361    30.7
# 362    28.4
# 363    19.9
# 364    26.9
# 365    30.2
# Name: MaxTemp, Length: 366, dtype: float64

# %%
temp9am = pd.Series(b['Temp9am'],name='Temp9am')
temp9am
# Out:
# 0      14.4
# 1      17.5
# 2      15.4
# 3      13.5
# 4      11.1
# 5      10.9
# 6      12.4
# 7      12.1
# 8      14.1
# 9      13.3
# 10     14.6
# 11     16.8
# 12     17.0
# 13     19.7
# 14     18.7
# 15     19.1
# 16     20.2
# 17     20.1
# 18     20.2
# 19     22.8
# 20     22.2
# 21     16.5
# 22     14.0
# 23     17.8
# 24     16.8
# 25     19.8
# 26     16.5
# 27     18.8
# 28     18.9
# 29     17.3
#        ...
# 336    19.0
# 337    22.5
# 338    14.5
# 339    11.7
# 340    12.8
# 341     6.9
# 342     7.2
# 343     8.1
# 344    10.0
# 345    13.6
# 346    12.6
# 347    16.3
# 348    14.5
# 349    11.6
# 350     9.6
# 351    11.6
# 352    12.7
# 353    16.8
# 354    16.4
# 355    11.4
# 356     8.3
# 357     9.1
# 358     9.4
# 359    12.0
# 360    16.3
# 361    20.4
# 362    17.2
# 363    14.5
# 364    15.8
# 365    23.8
# Name: Temp9am, Length: 366, dtype: float64

# %%
temp3pm = pd.Series(b['Temp3pm'],name='Temp3pm')
temp3pm
# Out:
# 0      23.6
# 1      25.7
# 2      20.2
# 3      14.1
# 4      15.4
# 5      14.8
# 6      17.3
# 7      15.5
# 8      18.9
# 9      21.7
# 10     24.0
# 11     26.0
# 12     27.1
# 13     30.7
# 14     30.4
# 15     30.7
# 16     29.8
# 17     28.6
# 18     31.2
# 19     32.0
# 20     32.8
# 21     18.3
# 22     16.8
# 23     22.8
# 24     27.3
# 25     25.1
# 26     21.2
# 27     26.7
# 28     19.7
# 29     23.2
#        ...
# 336    26.7
# 337    28.4
# 338    19.3
# 339    19.8
# 340    16.2
# 341    14.6
# 342    16.6
# 343    18.8
# 344    21.4
# 345    20.6
# 346    22.3
# 347    23.2
# 348    19.4
# 349    18.4
# 350    19.2
# 351    21.9
# 352    23.7
# 353    27.4
# 354    26.3
# 355    18.5
# 356    14.3
# 357    16.3
# 358    19.1
# 359    24.8
# 360    25.9
# 361    30.0
# 362    28.2
# 363    18.3
# 364    25.9
# 365    28.6
# Name: Temp3pm, Length: 366, dtype: float64
